# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('50_Startups.csv')
data.shape
# Out:
# (50, 5)

# %%
data.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %% [markdown]
# ## Bu veri seti, 50 farklı startup şirketinin çeşitli harcamalarını ve kârlılıklarını içermektedir.
#
# R&D Spend (Ar-Ge Harcaması): Şirketin araştırma ve geliştirme (Ar-Ge) için harcadığı tutar.
# Administration (Yönetim Harcaması): Şirketin yönetim giderleri için harcadığı tutar.
# Marketing Spend (Pazarlama Harcaması): Şirketin pazarlama ve reklam faaliyetleri için harcadığı tutar.
# State (Eyalet): Şirketin faaliyet gösterdiği eyalet (örneğin, New York, California, Florida).
# Profit (Kâr): Şirketin elde ettiği toplam kâr.
# Bu veri seti, startup'ların çeşitli harcama kalemleri ile kârlılıkları arasındaki ilişkileri analiz   etmek için kullanılabilir. Örneğin, Ar-Ge veya pazarlama harcamalarının kârlılık üzerindeki etkisini   incelemek için uygun bir veri setidir.

# %% [markdown]
# Öncelikle tek tek sütünlardaki Nan değerler kontrol edildi.Nan değerler varsa silme işlemi için fakat boş değer olmadığı tespit edildi.

# %%
print(f"R&D Spend Sütünu Boş Değer Sayisi:{data["R&D Spend"].isna().sum()}")
print(f"Administration Sütünu Boş Değer Sayisi:{data["Administration"].isna().sum()}")
print(f"Marketing Spend Sütünu Boş Değer Sayisi:{data["Marketing Spend"].isna().sum()}")
print(f"State Sütünu Boş Değer Sayisi:{data["State"].isna().sum()}")
print(f"Profit Sütünu Boş Değer Sayisi:{data["Profit"].isna().sum()}")
# Out:
# R&D Spend Sütünu Boş Değer Sayisi:0
# Administration Sütünu Boş Değer Sayisi:0
# Marketing Spend Sütünu Boş Değer Sayisi:0
# State Sütünu Boş Değer Sayisi:0
# Profit Sütünu Boş Değer Sayisi:0

# %% [markdown]
# ## 1.GÖREV : R&D Harcaması ve Kâr Arasındaki İlişki (Scatter Plot): Ar-Ge harcamaları ile kâr arasındaki ilişkiyi gösteren bir dağılım grafiği.

# %%
# Kodu buraya yazınız 
RD=data["R&D Spend"].values
profit=data["Profit"].values
plt.figure(figsize=(7,5))
plt.scatter(x=RD,y=profit)
plt.xlabel("R&D Spend")
plt.ylabel("Profit")
#plt.grid(True)
plt.style.use('ggplot')
plt.show()

# %% [markdown]
# ## 2.GÖREV: Yönetim Harcamaları ve Kâr Arasındaki İlişki (Scatter Plot): Yönetim harcamaları ile kâr arasındaki ilişkiyi gösteren bir dağılım grafiği.

# %%
# Kodu buraya yazınız 
# Kodu buraya yazınız 
# Kodu buraya yazınız 
ads=data["Administration"].values
profit=data["Profit"].values
plt.figure(figsize=(7,5))
plt.scatter(x=RD,y=profit)
plt.xlabel("Administration")
plt.ylabel("Profit")
plt.style.use('ggplot')
plt.show()

# %% [markdown]
# ## 3. GÖREV: Eyaletlere Göre Ortalama Kâr (Bar Chart): Farklı eyaletlerdeki startup'ların ortalama kârlarını karşılaştıran bir çubuk grafik.

# %%
data2=data[["State","Profit"]].groupby("State").sum()
print(data2.index)
print(data2.columns)
# Out:
# Index(['California', 'Florida', 'New York'], dtype='object', name='State')
# Index(['Profit'], dtype='object')

# %%
# Kodu buraya yazınız 
data2=data[["State","Profit"]].groupby("State").sum() #Öncelikle gruplama işlemi ile şehirlerdeki toplam kar bulundu.
pieValue=data2["Profit"].values
plt.figure(figsize=(7,7))
plt.pie(pieValue,labels=data2["Profit"].index,autopct='%1.1f%%',explode=[0, 0.05, 0.1])
plt.show()

# %% [markdown]
# ## 4. GÖREV: Harcama Türlerinin Karşılaştırması (Boxplot): R&D, yönetim ve pazarlama harcamalarının dağılımını karşılaştıran bir kutu grafiği.

# %%
# Kodu buraya yazınız 
rdSpend=data["R&D Spend"].values
adSpend=data["Administration"].values
marSpend=data["Administration"].values
plt.figure(figsize=(7,7))
plt.boxplot([rdSpend,adSpend,marSpend],labels=["R&D Spend","Administration","Administration"])

plt.ylabel("Spend")
plt.show()
# Out:
# C:\Users\dilar\AppData\Local\Temp\ipykernel_3316\4117472312.py:6: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([rdSpend,adSpend,marSpend],labels=["R&D Spend","Administration","Administration"])

# %%
data
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# 12   93863.75       127320.38        249839.44     Florida  141585.52
# 13   91992.39       135495.07        252664.93  California  134307.35
# 14  119943.24       156547.42        256512.92     Florida  132602.65
# 15  114523.61       122616.84        261776.23    New York  129917.04
# 16   78013.11       121597.55        264346.06  California  126992.93
# 17   94657.16       145077.58        282574.31    New York  125370.37
# 18   91749.16       114175.79        294919.57     Florida  124266.90
# 19   86419.70       153514.11             0.00    New York  122776.86
# 20   76253.86       113867.30        298664.47  California  118474.03
# 21   78389.47       153773.43        299737.29    New York  111313.02
# 22   73994.56       122782.75        303319.26     Florida  110352.25
# 23   67532.53       105751.03        304768.73     Florida  108733.99
# 24   77044.01        99281.34        140574.81    New York  108552.04
# 25   64664.71       139553.16        137962.62  California  107404.34
# 26   75328.87       144135.98        134050.07     Florida  105733.54
# 27   72107.60       127864.55        353183.81    New York  105008.31
# 28   66051.52       182645.56        118148.20     Florida  103282.38
# 29   65605.48       153032.06        107138.38    New York  101004.64
# 30   61994.48       115641.28         91131.24     Florida   99937.59
# 31   61136.38       152701.92         88218.23    New York   97483.56
# 32   63408.86       129219.61         46085.25  California   97427.84
# 33   55493.95       103057.49        214634.81     Florida   96778.92
# 34   46426.07       157693.92        210797.67  California   96712.80
# 35   46014.02        85047.44        205517.64    New York   96479.51
# 36   28663.76       127056.21        201126.82     Florida   90708.19
# 37   44069.95        51283.14        197029.42  California   89949.14
# 38   20229.59        65947.93        185265.10    New York   81229.06
# 39   38558.51        82982.09        174999.30  California   81005.76
# 40   28754.33       118546.05        172795.67  California   78239.91
# 41   27892.92        84710.77        164470.71     Florida   77798.83
# 42   23640.93        96189.63        148001.11  California   71498.49
# 43   15505.73       127382.30         35534.17    New York   69758.98
# 44   22177.74       154806.14         28334.72  California   65200.33
# 45    1000.23       124153.04          1903.93    New York   64926.08
# 46    1315.46       115816.21        297114.46     Florida   49490.75
# 47       0.00       135426.92             0.00  California   42559.73
# 48     542.05        51743.15             0.00    New York   35673.41
# 49       0.00       116983.80         45173.06  California   14681.40
